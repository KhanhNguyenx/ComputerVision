# %%
from PIL import Image

# %%
dir = 'C:/Users/ADMIN/Pictures/Saved Pictures'

# %%
image_path = dir +'/Bill.jpg'
print(image_path)
# Out:
# C:/Users/ADMIN/Pictures/Saved Pictures/Bill.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x313>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (250, 313)

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
