# %%
from PIL import Image
from imgTools import *
from IPython.display import display # to display images
dir = 'C:/Users/ADMIN/Pictures/Saved Pictures/Bill.jpg'
img = load_image(dir)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x313>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=250x313>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=250x313>
# <PIL.Image.Image image mode=L size=250x313>
# <PIL.Image.Image image mode=L size=250x313>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=250x313>

# %%
merged_image =  Image.merge("RGB", ( green_band,red_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=250x313>
