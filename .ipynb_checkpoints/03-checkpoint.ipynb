# %%
from PIL import Image
from imgTools import *
from IPython.display import display # to display images

# %%
my_path = 'C:/Users/ADMIN/Pictures/Saved Pictures/trump.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1920x1255>

# %%
print(img.size)
# Out:
# (1920, 1255)

# %%
new_size = (200,200)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
new_img_01_path = my_path + '/new_01.JPG'
new_image.save(new_img_01_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 new_img_01_path = my_path + '/new_01.JPG'
# ----> 2 new_image.save(new_img_01_path)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:2563, in Image.save(self, fp, format, **params)
#    2561         fp = builtins.open(filename, "r+b")
#    2562     else:
# -> 2563         fp = builtins.open(filename, "w+b")
#    2564 else:
#    2565     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ADMIN\\Pictures\\Saved Pictures\\trump.png\\new_01.JPG'
