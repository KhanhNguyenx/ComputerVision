# %%
# Import lớp Image
from PIL import Image
from imgTools import *
from IPython.display import display # to display images

# %%
my_path = 'D:/Dowload/img/trump.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x811>

# %%
print(img.size)
# Out:
# (640, 811)

# %%
new_size = (400,600)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x600>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=39x50>

# %%
dir = 'C:/Users/ADMIN/Pictures/Saved Pictures'
new_img_path = dir + '/img.PNG'
img.save(new_img_path)

# %%
img.close()
