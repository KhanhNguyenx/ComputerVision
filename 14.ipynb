# %%
import numpy as np
from PIL import Image

def average_images(image_list):
    total_array = np.array(Image.open(image_list[0]), 'f')
    count=1

    for image_path in image_list[1:]:
        try:
            image_array = np.array(Image.open(image_path), 'f')
            total_array += image_array
            count=count+1
        except:
            print("Skip ", image_path);

    average_array = total_array / count

    average_image = Image.fromarray(average_array.astype('uint8'))

    return average_image

my_path_1 = 'C:/Users/ADMIN/Pictures/Saved Pictures/img/cho.jpg'
my_path_2 = 'C:/Users/ADMIN/Pictures/Saved Pictures/img/meo.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# Skip  C:/Users/ADMIN/Pictures/Saved Pictures/img/meo.jpg
# <PIL.Image.Image image mode=RGB size=1500x1214>

# %%
my_path_1 = 'C:/Users/ADMIN/Pictures/Saved Pictures/trump.png'
my_path_2 = 'C:/Users/ADMIN/Pictures/Saved Pictures/Bill.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# Skip  C:/Users/ADMIN/Pictures/Saved Pictures/Bill.jpg
# <PIL.Image.Image image mode=RGB size=640x811>
